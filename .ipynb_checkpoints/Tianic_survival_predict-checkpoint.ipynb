# %% [markdown]
# # 机器学习：预测泰坦尼克号灾难的幸存者
#
# From Kaggle: Machine Learning from Disaster
#
# https://www.kaggle.com/c/titanic

# %% [markdown]
# # 项目背景

# %% [markdown]
# - 泰坦尼克号的沉没是历史上最臭名昭著的海难之一。
#
#
# - 1912年4月15日，在她的处女航中，被普遍认为“沉没”的RMS泰坦尼克号与冰山相撞后沉没。不幸的是，船上没有足够的救生艇供所有人使用，导致2224名乘客和机组人员中的1502人死亡。
#
#
# - 尽管幸存有一些运气，但似乎有些人比其他人更有可能生存。

# %% [markdown]
# # 项目目标

# %% [markdown]
# - 在本项目中，我们将使用乘客数据（即姓名，年龄，性别，社会经济舱等）建立多个预测模型来回答：**“什么样的人更有可能生存？”** 。
#
#
# - 最终选出最优的算法模型，对泰坦尼克号沉船事故中哪些人会幸存下来进行预测。
#
#
# - 初步决定采用**`Accuracy(准确率)、F1score`**作为模型表现的评估指标。
#
#
# - F1score = 2×Precision×Recall / (Precision+Recall)
#
# ![precision_recall.png](attachment:precision_recall.png)

# %% [markdown]
# # 项目字典

# %% [markdown]
# - **Survived**：存活结果（0 = 存活；1 = 未存活）
# - **Pclass**：社会阶层（1 = 上层；2 = 中层；3 = 底层）
# - **Name**：乘客姓名
# - **Sex**：乘客性别
# - **Age**：乘客年龄（某些条目为 `NaN`）
# - **SibSp**：一起上船的兄弟姐妹和配偶人数
# - **Parch**：一起上船的父母和子女人数
# - **Ticket**：乘客的票号
# - **Fare**：乘客支付的票价
# - **Cabin**：乘客的客舱号（某些条目为 `NaN`）
# - **Embarked**：乘客的登船港（C = 瑟堡；Q = 皇后镇；S = 南安普顿）

# %% [markdown]
# `**Variable Notes**`
#
# - pclass: A proxy for socio-economic status (SES)
#     - 1st = Upper
#     - 2nd = Middle
#     - 3rd = Lower
#
# - age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# - sibsp: The dataset defines family relations in this way...
# - Sibling = brother, sister, stepbrother, stepsister
# - Spouse = husband, wife (mistresses and fiancés were ignored)
#
# - parch: The dataset defines family relations in this way...
# - Parent = mother, father
# - Child = daughter, son, stepdaughter, stepson
# - Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# # 数据预处理

# %% [markdown]
# ## 数据加载

# %%
# 导入标准库
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from pandas.plotting import scatter_matrix

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier

from sklearn.metrics import accuracy_score, f1_score, make_scorer
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
df_train = pd.read_csv('titanic_data_train.csv')
df_test_features = pd.read_csv('titanic_data_test.csv')
df_test_label = pd.read_csv('gender_submission.csv')

# %% [markdown]
# ## 数据评估

# %%
df_train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_test_features.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
df_test_label.head(3)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0

# %%
print('The train dataset:',df_train.shape)
print('The features of test dataset:',df_test_features.shape)
print('The label of test dataset:',df_test_label.shape)
# Out:
# The train dataset: (891, 12)
# The features of test dataset: (418, 11)
# The label of test dataset: (418, 2)

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df_test_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df_test_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
# PassengerId    418 non-null int64
# Survived       418 non-null int64
# dtypes: int64(2)
# memory usage: 6.6 KB

# %%
# 查看各列数据概况
col_list = df_train.columns
for i in col_list:
    
    print('Column name:',i)
    print('-------------------------------')
    print(df_train[i].value_counts().nlargest(20))
    print('\n')
# Out:
# Column name: PassengerId
# -------------------------------
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# Name: PassengerId, dtype: int64
#
#
# Column name: Survived
# -------------------------------
# 0    549
# 1    342
# Name: Survived, dtype: int64
#
#
# Column name: Pclass
# -------------------------------
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
#
#
# Column name: Name
# -------------------------------
# Bowen, Mr. David John "Dai"                                  1
# Isham, Miss. Ann Elizabeth                                   1
# Rekic, Mr. Tido                                              1
# Hansen, Mr. Henry Damsgaard                                  1
# Foo, Mr. Choong                                              1
# Baxter, Mrs. James (Helene DeLaudeniere Chaput)              1
# Windelov, Mr. Einar                                          1
# Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)    1
# Rugg, Miss. Emily                                            1
# Petroff, Mr. Pastcho ("Pentcho")                             1
# Bryhl, Mr. Kurt Arnold Gottfrid                              1
# Leonard, Mr. Lionel                                          1
# Davison, Mrs. Thomas Henry (Mary E Finck)                    1
# Stankovic, Mr. Ivan                                          1
# Taussig, Mrs. Emil (Tillie Mandelbaum)                       1
# Becker, Master. Richard F                                    1
# Peter, Mrs. Catherine (Catherine Rizk)                       1
# Flynn, Mr. James                                             1
# Cameron, Miss. Clear Annie                                   1
# Porter, Mr. Walter Chamberlain                               1
# Name: Name, dtype: int64
#
#
# Column name: Sex
# -------------------------------
# male      577
# female    314
# Name: Sex, dtype: int64
#
#
# Column name: Age
# -------------------------------
# 24.0    30
# 22.0    27
# 18.0    26
# 19.0    25
# 30.0    25
# 28.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 32.0    18
# 27.0    18
# 35.0    18
# 26.0    18
# 16.0    17
# 31.0    17
# 20.0    15
# 33.0    15
# 23.0    15
# 34.0    15
# Name: Age, dtype: int64
#
#
# Column name: SibSp
# -------------------------------
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
#
#
# Column name: Parch
# -------------------------------
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64
#
#
# Column name: Ticket
# -------------------------------
# 347082          7
# CA. 2343        7
# 1601            7
# 3101295         6
# 347088          6
# CA 2144         6
# S.O.C. 14879    5
# 382652          5
# 113781          4
# 4133            4
# 347077          4
# W./C. 6608      4
# 2666            4
# LINE            4
# 349909          4
# PC 17757        4
# 113760          4
# 19950           4
# 17421           4
# 239853          3
# Name: Ticket, dtype: int64
#
#
# Column name: Fare
# -------------------------------
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 26.5500    15
# 0.0000     15
# 7.2292     15
# 7.8542     13
# 8.6625     13
# 7.2500     13
# 7.2250     12
# 16.1000     9
# 9.5000      9
# 24.1500     8
# 15.5000     8
# 56.4958     7
# Name: Fare, dtype: int64
#
#
# Column name: Cabin
# -------------------------------
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
# E101           3
# D              3
# F2             3
# D33            2
# B22            2
# B28            2
# B5             2
# C68            2
# E8             2
# E25            2
# B51 B53 B55    2
# B20            2
# E44            2
# C78            2
# D36            2
# Name: Cabin, dtype: int64
#
#
# Column name: Embarked
# -------------------------------
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
print(df_train.duplicated().sum())
print(df_test_features.duplicated().sum())
print(df_test_label.duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# - `**评估结果：**`
#
#
#     - 数据集titanic_data_train.csv中含有Survived标签列，为后期训练的label，需要将其单独分离出来
#     - 数据集titanic_data_test.csv中仅有对应乘客的features，将通过模型进行预测，输出01结果，形式如gender_submission.csv
#     - 训练集共891行数据，测试集共418行数据，乘客拥用11个特征。
#     - 数据集titanic_data_train.csv中的Age、Cabin、Embarked列分别存在177、687、2个NaN；数据集titanic_data_test.csv中的Age、Fare、Cabin分别存在86、1、327个NaN。
#     - Ticket列数据存在多种形式
#     - Cabin列数据存在一格写多个values的情况，可能是同行多人导致。
#     - 数据集中各列value暂未发现格式不妥的情况。
#     - 数据集中均不存在重复项

# %% [markdown]
# ## 数据清理

# %%
# 数据备份
df = df_train.copy()
df1 = df_test_features.copy()

# %% [markdown]
# ### 整洁度
# 经观察，并无整洁度问题，唯一需要进行的结构调整，是将Survived列从数据集中分离出来。

# %%
train_label = df['Survived']
train = df.drop(['Survived'],axis=1)

# %%
train.sample()
# Out:
#      PassengerId  Pclass                    Name   Sex   Age  SibSp  Parch  \
# 810          811       3  Alexander, Mr. William  male  26.0      0      0
#
#     Ticket    Fare Cabin Embarked
# 810   3474  7.8875   NaN        S

# %% [markdown]
# ### 质量维度

# %% [markdown]
# - 处理数据集中的NaN值，尝试进行填充：首先填充0查看训练结果，之后再尝试进行合理化填充，之后核实训练结果是否改善。
# - 观察和清理Ticket、Cabin列中的values格式问题。

# %%
train.sample(3)
# Out:
#      PassengerId  Pclass                      Name     Sex   Age  SibSp  \
# 318          319       1  Wick, Miss. Mary Natalie  female  31.0      0
# 517          518       3         Ryan, Mr. Patrick    male   NaN      0
# 262          263       1         Taussig, Mr. Emil    male  52.0      1
#
#      Parch  Ticket      Fare Cabin Embarked
# 318      2   36928  164.8667    C7        S
# 517      0  371110   24.1500   NaN        Q
# 262      1  110413   79.6500   E67        S

# %% [markdown]
# #### NaN值

# %% [markdown]
# > `**用0填充NaN**`

# %%
train = train.fillna(0)
train.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
test = df1.fillna(0)
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# #### Ticket列

# %% [markdown]
# > `**清理Ticket列格式问题**`

# %%
#对训练集进行Ticket清洗
train.Ticket.head(10)
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# 5              330877
# 6               17463
# 7              349909
# 8              347742
# 9              237736
# Name: Ticket, dtype: object

# %%
not_nan = train.Ticket.str.extract('([A-Z]+/?\w*[\s.]*\d*)')
not_nan.head(5)
# Out:
#                   0
# 0         A/5 21171
# 1          PC 17599
# 2  STON/O2. 3101282
# 3               NaN
# 4               NaN

# %%
#仅返回非NaN数据行
train[not_nan.T.any()].Ticket.value_counts()
# Out:
# CA. 2343             7
# CA 2144              6
# S.O.C. 14879         5
# PC 17757             4
# W./C. 6608           4
# LINE                 4
# PC 17755             3
# SC/Paris 2123        3
# PC 17572             3
# F.C.C. 13529         3
# C.A. 31921           3
# C.A. 34651           3
# PC 17760             3
# PC 17582             3
# C.A. 37671           2
# C.A. 2315            2
# A/5. 3336            2
# PC 17593             2
# S.O./P.P. 3          2
# PC 17604             2
# P/PP 3381            2
# S.C./PARIS 2079      2
# PC 17558             2
# STON/O2. 3101279     2
# PC 17485             2
# PP 9549              2
# PC 17761             2
# C.A. 33112           2
# PC 17611             2
# PC 17569             2
#                     ..
# STON/O 2. 3101280    1
# C.A. 34260           1
# A/4 45380            1
# SOTON/O.Q. 392078    1
# PC 17756             1
# C 17369              1
# SOTON/OQ 392076      1
# A/5 21171            1
# PC 17759             1
# STON/O 2. 3101285    1
# STON/O 2. 3101274    1
# C.A./SOTON 34068     1
# C.A. 18723           1
# SC/AH 29037          1
# C.A. 29566           1
# SC/PARIS 2146        1
# Fa 265302            1
# A/5. 10482           1
# STON/O 2. 3101293    1
# PC 17475             1
# STON/O 2. 3101289    1
# A.5. 11206           1
# A/5. 13032           1
# PC 17612             1
# SO/C 14885           1
# STON/O 2. 3101288    1
# A/5 3536             1
# PC 17585             1
# SC/PARIS 2133        1
# C 7075               1
# Name: Ticket, Length: 167, dtype: int64

# %%
#仅返回为NaN数据行
train[not_nan.isnull().T.any()].Ticket.value_counts()
# Out:
# 1601       7
# 347082     7
# 3101295    6
# 347088     6
# 382652     5
# 4133       4
# 17421      4
# 2666       4
# 113781     4
# 113760     4
# 19950      4
# 349909     4
# 347077     4
# 24160      3
# 110152     3
# 248727     3
# 29106      3
# 110413     3
# 35273      3
# 371110     3
# 13502      3
# 230080     3
# 363291     3
# 347742     3
# 345773     3
# 239853     3
# 250644     2
# 2627       2
# 367230     2
# 2651       2
#           ..
# 2623       1
# 349231     1
# 392091     1
# 111240     1
# 27042      1
# 392092     1
# 239856     1
# 239855     1
# 350036     1
# 226593     1
# 345364     1
# 17466      1
# 7540       1
# 383121     1
# 323951     1
# 236853     1
# 349218     1
# 220367     1
# 2694       1
# 349201     1
# 364498     1
# 347085     1
# 2625       1
# 112053     1
# 364850     1
# 4134       1
# 11774      1
# 12233      1
# 13049      1
# 368323     1
# Name: Ticket, Length: 514, dtype: int64

# %%
#将Ticket中填写为LINE值变为0
line_tozero = (lambda x : 0 if x=='LINE' else x)
train['Ticket']=train.Ticket.apply(line_tozero)

# %% [markdown]
# **`经以上数据剥离结果观察，Ticket编码应为纯数字，长度在3—7位数，所以需要将含有字母、符号的数据进行清理，仅留下纯数字`**

# %%
train['Ticket'] = train.Ticket.str.split().str[-1:].str[0].fillna(0).values.astype('int')

# %%
#核实数据清理情况
train.Ticket.value_counts()
# Out:
# 1601       7
# 2343       7
# 347082     7
# 2144       6
# 3101295    6
# 347088     6
# 14879      5
# 382652     5
# 0          4
# 4133       4
# 347077     4
# 113781     4
# 19950      4
# 17757      4
# 113760     4
# 2666       4
# 17421      4
# 6608       4
# 349909     4
# 31921      3
# 248727     3
# 17474      3
# 345773     3
# 239853     3
# 2123       3
# 230080     3
# 13529      3
# 34651      3
# 110152     3
# 17582      3
#           ..
# 367228     1
# 3101307    1
# 3101305    1
# 2680       1
# 2677       1
# 3101289    1
# 3101298    1
# 3101296    1
# 3101294    1
# 2669       1
# 2667       1
# 2690       1
# 27267      1
# 6609       1
# 3101293    1
# 312991     1
# 315037     1
# 36967      1
# 244270     1
# 244373     1
# 236171     1
# 4134       1
# 2693       1
# 350043     1
# 2700       1
# 2697       1
# 111240     1
# 2695       1
# 2694       1
# 348121     1
# Name: Ticket, Length: 679, dtype: int64

# %%
#对测试集进行Ticket清洗
test_notnull = test.Ticket.str.extract('([A-Z]+/?\w*[\s.]*\d*)')
test_notnull
# Out:
#                     0
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9           A/4 48871
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                 W.
# 15      SC/PARIS 2167
# 16                NaN
# 17                NaN
# 18   STON/O2. 3101270
# 19                NaN
# 20           PC 17603
# 21            C 17368
# 22           PC 17598
# 23           PC 17597
# 24           PC 17608
# 25          A/5. 3337
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ..                ...
# 388               NaN
# 389               NaN
# 390               NaN
# 391          PC 17592
# 392                C.
# 393                C.
# 394               NaN
# 395               NaN
# 396               NaN
# 397               NaN
# 398               NaN
# 399               NaN
# 400               NaN
# 401               NaN
# 402               NaN
# 403               NaN
# 404               NaN
# 405     SC/PARIS 2166
# 406               NaN
# 407               NaN
# 408               NaN
# 409          SOTON/O.
# 410               NaN
# 411               NaN
# 412               NaN
# 413               A.5
# 414          PC 17758
# 415          SOTON/O.
# 416               NaN
# 417               NaN
#
# [418 rows x 1 columns]

# %%
test[test_notnull.T.any()].Ticket
# Out:
# 9               A/4 48871
# 14            W.E.P. 5734
# 15          SC/PARIS 2167
# 18       STON/O2. 3101270
# 20               PC 17603
# 21                C 17368
# 22               PC 17598
# 23               PC 17597
# 24               PC 17608
# 25              A/5. 3337
# 30             SC/AH 3085
# 31             C.A. 31029
# 32              C.A. 2315
# 33             W./C. 6607
# 42     SOTON/O.Q. 3101263
# 45      STON/O 2. 3101291
# 46               PC 17594
# 49             C.A. 37671
# 51          SC/PARIS 2168
# 54            SC/A.3 2861
# 59               PC 17608
# 64               PC 17608
# 65           F.C.C. 13534
# 73               PC 17562
# 81               PC 17483
# 87              A/4 31416
# 92             F.C. 12750
# 97      STON/O 2. 3101268
# 99             A./5. 3338
# 105                C 4001
#               ...
# 319            C.A. 31029
# 325    SOTON/O.Q. 3101309
# 327              PC 17585
# 330            C.A. 33112
# 331              PC 17580
# 338            C.A. 31029
# 340            C.A. 15185
# 342              CA. 2343
# 343              PC 17755
# 344              A/5. 851
# 349          F.C.C. 13528
# 350              PC 17759
# 351          F.C.C. 13540
# 352          S.O.C. 14879
# 354             C.A. 2315
# 360              CA. 2343
# 361       S.C./PARIS 2079
# 362              CA 31352
# 365              CA. 2343
# 369         SC/PARIS 2147
# 375              PC 17608
# 384         SC/PARIS 2159
# 391              PC 17592
# 392             C.A. 2673
# 393            C.A. 30769
# 405         SC/PARIS 2166
# 409    SOTON/O.Q. 3101315
# 413             A.5. 3236
# 414              PC 17758
# 415    SOTON/O.Q. 3101262
# Name: Ticket, Length: 122, dtype: object

# %%
test[test_notnull.isnull().T.any()].Ticket
# Out:
# 0       330911
# 1       363272
# 2       240276
# 3       315154
# 4      3101298
# 5         7538
# 6       330972
# 7       248738
# 8         2657
# 10      349220
# 11         694
# 12       21228
# 13       24065
# 16      233734
# 17        2692
# 19        2696
# 26      113509
# 27        2698
# 28      113054
# 29        2662
# 34       13236
# 35        2682
# 36      342712
# 37      315087
# 38      345768
# 39        1601
# 40      349256
# 41      113778
# 43      237249
# 44       11753
#         ...
# 379     347077
# 380     366713
# 381     330910
# 382     364498
# 383     376566
# 385     220845
# 386     349911
# 387     244346
# 388     364858
# 389     349909
# 390      12749
# 394     315153
# 395      13695
# 396     371109
# 397      13567
# 398     347065
# 399      21332
# 400      36928
# 401      28664
# 402     112378
# 403     113059
# 404      17765
# 406      28666
# 407     113503
# 408     334915
# 410     365237
# 411      19928
# 412     347086
# 416     359309
# 417       2668
# Name: Ticket, Length: 296, dtype: object

# %%
test['Ticket'] = test.Ticket.str.split().str[-1:].str[0]

# %%
test.Ticket.value_counts()
# Out:
# 17608      5
# 2343       4
# 113503     4
# 347077     3
# 16966      3
# 3101315    3
# 220845     3
# 31029      3
# 17483      3
# 13534      2
# 33638      2
# 315153     2
# 13236      2
# 24065      2
# 2673       2
# 29103      2
# 350405     2
# 31352      2
# 113781     2
# 28220      2
# 13508      2
# 6607       2
# 4001       2
# 2650       2
# 17756      2
# 2          2
# 14879      2
# 2315       2
# 13050      2
# 347072     2
#           ..
# 65305      1
# 244360     1
# 347469     1
# 21175      1
# 111163     1
# 330844     1
# 4133       1
# 3101268    1
# 34050      1
# 17603      1
# 237670     1
# 236853     1
# 248738     1
# 2678       1
# 368573     1
# 2692       1
# 30769      1
# 368783     1
# 349256     1
# 3337       1
# 17580      1
# 2656       1
# 349226     1
# 3085       1
# 347465     1
# 350053     1
# 347075     1
# 5734       1
# 244358     1
# 347086     1
# Name: Ticket, Length: 362, dtype: int64

# %% [markdown]
# #### Cabin列

# %% [markdown]
# > `**清理Cabin列格式问题**`

# %%
train.Cabin.value_counts().head(10)
# Out:
# 0              687
# G6               4
# C23 C25 C27      4
# B96 B98          4
# D                3
# E101             3
# F33              3
# C22 C26          3
# F2               3
# B58 B60          2
# Name: Cabin, dtype: int64

# %%
train.iloc[85:100].Cabin
# Out:
# 85              0
# 86              0
# 87              0
# 88    C23 C25 C27
# 89              0
# 90              0
# 91              0
# 92            E31
# 93              0
# 94              0
# 95              0
# 96             A5
# 97        D10 D12
# 98              0
# 99              0
# Name: Cabin, dtype: object

# %%
train.iloc[85:100].Cabin.str.extract('(\w+\s+[\w\s]*)')
# Out:
#               0
# 85          NaN
# 86          NaN
# 87          NaN
# 88  C23 C25 C27
# 89          NaN
# 90          NaN
# 91          NaN
# 92          NaN
# 93          NaN
# 94          NaN
# 95          NaN
# 96          NaN
# 97      D10 D12
# 98          NaN
# 99          NaN

# %%
two_three = train.Cabin.str.extract('(\w+\s+[\w\s]*)')

# %%
train[two_three.T.any()].Cabin
# Out:
# 27         C23 C25 C27
# 75               F G73
# 88         C23 C25 C27
# 97             D10 D12
# 118            B58 B60
# 128              F E69
# 297            C22 C26
# 299            B58 B60
# 305            C22 C26
# 311    B57 B59 B63 B66
# 341        C23 C25 C27
# 390            B96 B98
# 435            B96 B98
# 438        C23 C25 C27
# 498            C22 C26
# 679        B51 B53 B55
# 699              F G63
# 700            C62 C64
# 715              F G73
# 742    B57 B59 B63 B66
# 763            B96 B98
# 789            B82 B84
# 802            B96 B98
# 872        B51 B53 B55
# Name: Cabin, dtype: object

# %%
train[two_three.isnull().T.any()].Cabin
# Out:
# 0         0
# 1       C85
# 2         0
# 3      C123
# 4         0
# 5         0
# 6       E46
# 7         0
# 8         0
# 9         0
# 10       G6
# 11     C103
# 12        0
# 13        0
# 14        0
# 15        0
# 16        0
# 17        0
# 18        0
# 19        0
# 20        0
# 21      D56
# 22        0
# 23       A6
# 24        0
# 25        0
# 26        0
# 28        0
# 29        0
# 30        0
#        ...
# 860       0
# 861       0
# 862     D17
# 863       0
# 864       0
# 865       0
# 866       0
# 867     A24
# 868       0
# 869       0
# 870       0
# 871     D35
# 873       0
# 874       0
# 875       0
# 876       0
# 877       0
# 878       0
# 879     C50
# 880       0
# 881       0
# 882       0
# 883       0
# 884       0
# 885       0
# 886       0
# 887     B42
# 888       0
# 889    C148
# 890       0
# Name: Cabin, Length: 867, dtype: object

# %%
train[two_three.T.any()]
# Out:
#      PassengerId  Pclass                                               Name  \
# 27            28       1                     Fortune, Mr. Charles Alexander
# 75            76       3                            Moen, Mr. Sigurd Hansen
# 88            89       1                         Fortune, Miss. Mabel Helen
# 97            98       1                    Greenfield, Mr. William Bertram
# 118          119       1                           Baxter, Mr. Quigg Edmond
# 128          129       3                                  Peter, Miss. Anna
# 297          298       1                       Allison, Miss. Helen Loraine
# 299          300       1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 305          306       1                     Allison, Master. Hudson Trevor
# 311          312       1                         Ryerson, Miss. Emily Borie
# 341          342       1                     Fortune, Miss. Alice Elizabeth
# 390          391       1                         Carter, Mr. William Ernest
# 435          436       1                          Carter, Miss. Lucile Polk
# 438          439       1                                  Fortune, Mr. Mark
# 498          499       1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 679          680       1                 Cardeza, Mr. Thomas Drake Martinez
# 699          700       3           Humblen, Mr. Adolf Mathias Nicolai Olsen
# 700          701       1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 715          716       3         Soholt, Mr. Peter Andreas Lauritz Andersen
# 742          743       1              Ryerson, Miss. Susan Parker "Suzette"
# 763          764       1          Carter, Mrs. William Ernest (Lucile Polk)
# 789          790       1                           Guggenheim, Mr. Benjamin
# 802          803       1                Carter, Master. William Thornton II
# 872          873       1                           Carlsson, Mr. Frans Olof
#
#         Sex    Age  SibSp  Parch  Ticket      Fare            Cabin Embarked
# 27     male  19.00      3      2   19950  263.0000      C23 C25 C27        S
# 75     male  25.00      0      0  348123    7.6500            F G73        S
# 88   female  23.00      3      2   19950  263.0000      C23 C25 C27        S
# 97     male  23.00      0      1   17759   63.3583          D10 D12        C
# 118    male  24.00      0      1   17558  247.5208          B58 B60        C
# 128  female   0.00      1      1    2668   22.3583            F E69        C
# 297  female   2.00      1      2  113781  151.5500          C22 C26        S
# 299  female  50.00      0      1   17558  247.5208          B58 B60        C
# 305    male   0.92      1      2  113781  151.5500          C22 C26        S
# 311  female  18.00      2      2   17608  262.3750  B57 B59 B63 B66        C
# 341  female  24.00      3      2   19950  263.0000      C23 C25 C27        S
# 390    male  36.00      1      2  113760  120.0000          B96 B98        S
# 435  female  14.00      1      2  113760  120.0000          B96 B98        S
# 438    male  64.00      1      4   19950  263.0000      C23 C25 C27        S
# 498  female  25.00      1      2  113781  151.5500          C22 C26        S
# 679    male  36.00      0      1   17755  512.3292      B51 B53 B55        C
# 699    male  42.00      0      0  348121    7.6500            F G63        S
# 700  female  18.00      1      0   17757  227.5250          C62 C64        C
# 715    male  19.00      0      0  348124    7.6500            F G73        S
# 742  female  21.00      2      2   17608  262.3750  B57 B59 B63 B66        C
# 763  female  36.00      1      2  113760  120.0000          B96 B98        S
# 789    male  46.00      0      0   17593   79.2000          B82 B84        C
# 802    male  11.00      1      2  113760  120.0000          B96 B98        S
# 872    male  33.00      0      0     695    5.0000      B51 B53 B55        S

# %% [markdown]
# - 通过观察发现，Cabin拥有多个值的数据行，为同行的一家人，其位于同一个客舱中。
# - 主观判断认为，客舱的座位号并无区别意义，而所在客舱才是将船客区分开来的关键，即如客舱号C22，座位号22并无区别意义，字母C才是区别发关键信息。
# - 以下将对字母进行提取

# %%
#对训练集进行Cabin清洗
train['Cabin']=train.Cabin.str.split().str[-1].str[0]

# %%
train = train.fillna(0)

# %%
train.sample(3)
# Out:
#      PassengerId  Pclass                            Name     Sex   Age  SibSp  \
# 318          319       1        Wick, Miss. Mary Natalie  female  31.0      0
# 390          391       1      Carter, Mr. William Ernest    male  36.0      1
# 309          310       1  Francatelli, Miss. Laura Mabel  female  30.0      0
#
#      Parch  Ticket      Fare Cabin Embarked
# 318      2   36928  164.8667     C        S
# 390      2  113760  120.0000     B        S
# 309      0   17485   56.9292     E        C

# %%
train.Cabin.value_counts()
# Out:
# 0    687
# C     59
# B     47
# E     33
# D     33
# A     15
# F      9
# G      7
# T      1
# Name: Cabin, dtype: int64

# %%
#对测试集进行Cabin清洗
test['Cabin']=test.Cabin.str.split().str[-1].str[0].fillna(0)

# %%
test.sample(3)
# Out:
#      PassengerId  Pclass                      Name     Sex   Age  SibSp  \
# 157         1049       3  Lundin, Miss. Olga Elida  female  23.0      0
# 293         1185       1     Dodge, Dr. Washington    male  53.0      1
# 162         1054       2      Wright, Miss. Marion  female  26.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 157      0  347469   7.8542     0        S
# 293      1   33638  81.8583     A        S
# 162      0  220844  13.5000     0        S

# %%
test.Cabin.value_counts()
# Out:
# 0    327
# C     35
# B     18
# D     13
# E     11
# A      7
# F      5
# G      2
# Name: Cabin, dtype: int64

# %% [markdown]
# # 数据探索和可视化

# %%
train.sample(5)
# Out:
#      PassengerId  Pclass                                               Name  \
# 101          102       3                   Petroff, Mr. Pastcho ("Pentcho")
# 131          132       3                     Coelho, Mr. Domingos Fernandeo
# 670          671       2  Brown, Mrs. Thomas William Solomon (Elizabeth ...
# 561          562       3                                  Sivic, Mr. Husein
# 521          522       3                                    Vovk, Mr. Janko
#
#         Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 101    male   0.0      0      0   349215   7.8958     0        S
# 131    male  20.0      0      0  3101307   7.0500     0        S
# 670  female  40.0      1      1    29750  39.0000     0        S
# 561    male  40.0      0      0   349251   7.8958     0        S
# 521    male  22.0      0      0   349252   7.8958     0        S

# %%
scatter_matrix(train,alpha=0.2,figsize=(12,8));

# %% [markdown]
# ## 函数定义

# %%
# 定义函数category_plot，用于返回分类变量的柱状图，以便查看各类乘客的比例
# def category_plot(col_name):
#     train.groupby(col_name)['PassengerId'].sum().plot.bar();

# %% [markdown]
# ## 分类变量（bar）
# 通过将各分类变量绘制柱状图，从而对人数比例进行观察。

# %%
train.sample()
# Out:
#      PassengerId  Pclass                         Name   Sex  Age  SibSp  \
# 277          278       2  Parkes, Mr. Francis "Frank"  male  0.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 277      0  239853   0.0     0        S

# %%
plt.figure(figsize=[16,14])
base_color = sns.color_palette()[0]

col_list=['Pclass', 'Sex', 'SibSp', 'Parch','Cabin', 'Embarked']
i=0
for col_name in col_list:
    if i <=5:
        plt.subplot(3,2,i+1)
        i+=1
        train.groupby(col_name)['PassengerId'].sum().plot.bar(color=base_color)
        plt.xlabel(col_name,fontsize=15);

# %% [markdown]
# ## 数值变量（hist）

# %%
plt.figure(figsize=[16,10])
num_col_list=['Age','Ticket','Fare']

i=1
for col in num_col_list:
    if i <= 3:
        plt.subplot(2,2,i)
        i+=1
        train[col].plot.hist(bins=80)
        plt.xlabel(col,fontsize=15);

# %% [markdown]
# ## 双变量

# %%
train.sample()
# Out:
#      PassengerId  Pclass                         Name   Sex   Age  SibSp  \
# 672          673       2  Mitchell, Mr. Henry Michael  male  70.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 672      0   24580  10.5     0        S

# %%
def two_var_plot(x,y):
    sns.barplot(data=train,x=x,y=y,color=base_color);

# %%
plt.figure(figsize=[16,10])

plt.subplot(3,2,1)
two_var_plot('Pclass','Fare')

plt.subplot(3,2,2)
two_var_plot('Cabin','Fare')

plt.subplot(3,2,3)
two_var_plot('Embarked','Fare')

plt.subplot(3,2,4)
two_var_plot('Pclass','Age')

plt.subplot(3,2,5)
two_var_plot('Cabin','Age')

plt.subplot(3,2,6)
two_var_plot('Embarked','Age');

# %%
plt.scatter(data=train,x='Age',y='Fare');

# %% [markdown]
# # 特征工程
